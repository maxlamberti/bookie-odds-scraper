# %% [markdown]
# ## Exploring Betting Strategies using historical odds
#
# Datasource 1: https://www.indatabet.com/ft-free-2in1.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 = pd.read_csv('football_historical.csv', low_memory = False)

# %%
data1.head()
# Out:
#        YY    DD   MM       Date ID (FIFA) Country            League  \
# 0     NaN   NaN  NaN        NaN       NaN     NaN               NaN
# 1     NaN   NaN  NaN        NaN       NaN     NaN               NaN
# 2  2019.0  21.0  Aug  21/8/2019     EU CL  Europe  Champions League
# 3  2019.0  21.0  Aug  21/8/2019     EU CL  Europe  Champions League
# 4  2019.0  21.0  Aug  21/8/2019     EU CL  Europe  Champions League
#
#       Season                     Teams              Unnamed: 9     ...      \
# 0        NaN                      Home                    Away     ...
# 1        NaN                       NaN                     NaN     ...
# 2  2019/2020           D. Zagreb (Cro)         Rosenborg (Nor)     ...
# 3  2019/2020  Olympiacos Piraeus (Gre)         Krasnodar (Rus)     ...
# 4  2019/2020          Young Boys (Sui)  FK Crvena zvezda (Srb)     ...
#
#   Payout, % FT Moneyline.1 Unnamed: 28 Unnamed: 29 Payout, %.1 FT TG 2.5  \
# ...

# %%
data1.columns
# Out:
# Index(['YY', 'DD', 'MM', 'Date', 'ID (FIFA)', 'Country', 'League', 'Season',
#        'Teams', 'Unnamed: 9', 'Final Scores', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'ET/Pen/Awd', '1st Half Scores', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', '2nd Half Scores', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'FT Moneyline', 'Unnamed: 24',
#        'Unnamed: 25', 'Payout, %', 'FT Moneyline.1', 'Unnamed: 28',
#        'Unnamed: 29', 'Payout, %.1', 'FT TG 2.5', 'Unnamed: 32', 'FT TG 2.5.1',
#        'Unnamed: 34', 'Unnamed: 35'],
#       dtype='object')

# %%
#Take Relevant Data
hist_data = pd.DataFrame()


hist_data['dates'] = data1['Date'][2:]
hist_data['ID'] = data1['ID (FIFA)'][2:] #identifies both country and league
hist_data['season'] = data1['Season'][2:]
hist_data['home_team'] = data1['Teams'][2:]
hist_data['away_team'] = data1['Unnamed: 9'][2:]
hist_data['result'] = data1['Unnamed: 12'][2:] #H - home wins, D - Draw, A - away wins
hist_data['pinnacle_home_odds'] = data1['FT Moneyline'][2:]
hist_data['pinnacle_draw_odds'] = data1['Unnamed: 24'][2:]
hist_data['pinnacle_away_odds'] = data1['Unnamed: 25'][2:]
hist_data['bet365_home_odds'] = data1['FT Moneyline.1'][2:]
hist_data['bet365_draw_odds'] = data1['Unnamed: 28'][2:]
hist_data['bet365_away_odds'] = data1['Unnamed: 29'][2:]

hist_data.head()
# Out:
#        dates     ID     season                 home_team  \
# 2  21/8/2019  EU CL  2019/2020           D. Zagreb (Cro)
# 3  21/8/2019  EU CL  2019/2020  Olympiacos Piraeus (Gre)
# 4  21/8/2019  EU CL  2019/2020          Young Boys (Sui)
# 5  20/8/2019  EU CL  2019/2020               APOEL (Cyp)
# 6  20/8/2019  EU CL  2019/2020            CFR Cluj (Rou)
#
#                 away_team result pinnacle_home_odds pinnacle_draw_odds  \
# 2         Rosenborg (Nor)      H               1.73               3.78
# 3         Krasnodar (Rus)      H               2.11               3.32
# 4  FK Crvena zvezda (Srb)      D               1.85               3.54
# 5              Ajax (Ned)      D               6.16               4.37
# 6     Slavia Prague (Cze)      A               2.86               3.06
#
#   pinnacle_away_odds bet365_home_odds bet365_draw_odds bet365_away_odds
# 2               5.12             1.72             3.75             4.50
# ...
